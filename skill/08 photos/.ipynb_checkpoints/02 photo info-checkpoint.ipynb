# %%
import glob

fpath = glob.glob('C:\aaa.gif')

# %%
from PIL import Image

# %%
fpath = glob.glob('C:\*.bmp')[0]
fpath
# Out:
# 'C:\\p6a_image_0.bmp'

# %%
img = Image.open(fpath)

# %%
img
# Out:
# <PIL.BmpImagePlugin.BmpImageFile image mode=RGB size=3840x1080 at 0x1249DDDC9A0>

# %%
img.size
# Out:
# (3840, 1080)

# %%
img.mode
# Out:
# 'RGB'

# %%
img.format
# Out:
# 'BMP'

# %%
img.thumbnail((512, 512))
img.size
# Out:
# (512, 144)

# %%
img
# Out:
# <PIL.BmpImagePlugin.BmpImageFile image mode=RGB size=512x144 at 0x1249DDDC9A0>

# %%
fpath = glob.glob('F:\\sahre\\1\\*.jpg')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-40-b24d114bd8cf> in <module>
# ----> 1 fpath = glob.glob('F:\\sahre\\1\\*.jpg')[0]
#
# IndexError: list index out of range

# %%
fpath[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-39-1acf6fd5e699> in <module>
# ----> 1 fpath[0]
#
# IndexError: list index out of range
